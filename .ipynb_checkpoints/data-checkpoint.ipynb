# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# 데이터는 df 라는 데이터 프레임에 담아서 다룹니다.
df = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_서울_202510.csv")
# df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 5
#       3 df = df.sample(frac=0.01)
#       4 df.head()
# ----> 5 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df = df.sample(frac=0.3) # 개발 단계에서는 50만개의 데이터는 너무 많으니 5천개의 데이터로 진행

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
df.head()
['상가업소번호','상호명','상권업종대분류명','상권업종중분류명', '상권업종소분류명', '표준산업분류명','시도명',  '시군구명', '행정동명', '법정동명','대지구분명','지번본번지','지번부번지','지번주소','도로명','건물본번지',
'건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보','호정보','경도','위도']
# Out:
#                       상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 424982  MA0101202502A0092203      와플대학방배캠퍼스  NaN        I2       음식      I210
# 62588   MA010120220813774513        한국에이치알엠  NaN        N1  시설관리·임대      N104
# 30817   MA010120220804162604       임성규법률사무소  NaN        M1    과학·기술      M103
# 345673  MA0101202502A0002092  칼퇴근김대리왕십리텐즈힐점  NaN        I2       음식      I211
# 173907  MA010120220808483493             니어  NaN        G2       소매      G209
#
#            상권업종중분류명 상권업종소분류코드   상권업종소분류명 표준산업분류코드  ...  \
# 424982        기타 간이    I21001       빵/도넛   I56194  ...
# 62588         고용 알선    N10401     고용 알선업   N75110  ...
# 30817         법무관련     M10301        변호사   M71101  ...
# 345673           주점    I21103     생맥주 전문   I56213  ...
# 173907  섬유·의복·신발 소매    G20901  남성 의류 소매업   G47411  ...
#
#                            건물관리번호       건물명                  도로명주소   구우편번호  \
# 424982  1165010100109230006000002   방배아크로타워    서울특별시 서초구 방배로13길 18  137843
# 62588   1144010400105440000003652        고려      서울특별시 마포구 큰우물로 76  121704
# 30817   1165010800116960014020080      나라빌딩  서울특별시 서초구 서초중앙로24길 19  137883
# 345673  1120010100108110000000001    텐즈힐아파트      서울특별시 성동구 마장로 137  133010
# 173907  1120011400106680070027731  층니어성수웨이브  서울특별시 성동구 서울숲4길 22-18  133824
#
#        신우편번호  동정보 층정보  호정보          경도         위도
# 424982  6683  NaN   1  NaN  126.995297  37.483132
# 62588   4167  NaN   4  NaN  126.945948  37.540766
# 30817   6604  NaN   7  NaN  127.015684  37.495042
# 345673  4700  221   1  NaN  127.025061  37.567824
# 173907  4768  NaN   4  NaN  127.043012  37.546834
#
# [5 rows x 39 columns]

# %%
df.describe()
# Out:
#          시도코드         시군구코드         행정동코드         법정동코드          지번코드  \
# count  5363.0   5363.000000  5.363000e+03  5.363000e+03  5.363000e+03
# mean     11.0  11459.231773  1.145984e+07  1.145934e+09  1.145934e+18
# std       0.0    196.769880  1.967589e+05  1.967632e+07  1.967632e+16
# min      11.0  11110.000000  1.111052e+07  1.111010e+09  1.111010e+18
# 25%      11.0  11290.000000  1.129061e+07  1.129013e+09  1.129013e+18
# 50%      11.0  11500.000000  1.150054e+07  1.150010e+09  1.150010e+18
# 75%      11.0  11650.000000  1.165054e+07  1.165011e+09  1.165011e+18
# max      11.0  11740.000000  1.174070e+07  1.174011e+09  1.174011e+18
#
#             대지구분코드        지번본번지        지번부번지         도로명코드        건물본번지  \
# count  5363.000000  5363.000000  4447.000000  5.363000e+03  5363.000000
# mean      1.001119   435.584934    30.637059  1.145959e+11   152.310647
# std       0.033433   447.656743    83.389857  1.967698e+09   278.599532
# min       1.000000     1.000000     1.000000  1.111020e+11     1.000000
# 25%       1.000000   103.000000     4.000000  1.129031e+11    19.000000
# 50%       1.000000   310.000000    10.000000  1.150030e+11    48.000000
# 75%       1.000000   652.000000    25.000000  1.165042e+11   170.000000
# max       2.000000  4975.000000  1528.000000  1.174049e+11  2942.000000
#
#             건물부번지          구우편번호        신우편번호  호정보           경도           위도
# count  745.000000    5363.000000  5363.000000  0.0  5363.000000  5363.000000
# mean     7.475168  137059.584188  5297.961402  NaN   126.993471    37.541911
# std      9.130313   14146.653234  2113.607420  NaN     0.081453     0.048645
# min      1.000000  100011.000000  1004.000000  NaN   126.794975    37.434636
# 25%      1.000000  131872.000000  3725.500000  NaN   126.924727    37.502057
# 50%      5.000000  137810.000000  5538.000000  NaN   127.009894    37.537177
# 75%     10.000000  150042.000000  6924.000000  NaN   127.052355    37.569996
# max     94.000000  158885.000000  8865.000000  NaN   127.175175    37.689531

# %%
#DB에 연결하기
engine = create_engine('mysql+pymysql://root:ehdalsdml_akfldkelql@3.39.42.231/market_data')

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_')
df = df.fillna('')

# %%
# 특정 컬럼만 INSERT
# 코드 말고 이름으로만 전체 데이터 입력
only_names = ['상가업소번호','상호명','상권업종대분류명','상권업종중분류명', '상권업종소분류명', '표준산업분류명','시도명',  '시군구명', '행정동명', '법정동명','대지구분명','지번본번지','지번부번지','지번주소','도로명','건물본번지',
'건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보','호정보','경도','위도']

def add_not_setting():
    df[names].to_sql(
        name='non_setting_data2',
        con=engine,
        if_exists='append',
        index=False
    )

add_not_setting()
# Out:
# 5363

# %%
def add_indexes_later():
    """이미 데이터가 있는 테이블에 인덱스 추가"""
    indexes = [
        "CREATE INDEX idx_sido ON store_data(sido)",
        "CREATE INDEX idx_upjong ON store_data(upjong)",
        "CREATE INDEX idx_sido_sigungu ON store_data(sido, sigungu)",
        "CREATE INDEX idx_reg_date ON store_data(reg_date)"
    ]
    
    with engine.connect() as conn:
        for sql in indexes:
            try:
                print(f"실행 중: {sql}")
                conn.execute(text(sql))
                conn.commit()
                print("✓ 완료")
            except Exception as e:
                print(f"✗ 에러: {e}")

add_indexes_later()
# Out:
# '하하'

# %%
def add_table_setting():
    """DB 스키마 생성 (인덱스 포함)"""
    with engine.connect() as conn:
        # 기존 테이블 삭제
        conn.execute(text("DROP TABLE IF EXISTS setting_data"))
        
        # 테이블 생성 (인덱스, 제약조건 포함)
        conn.execute(text("""
            CREATE TABLE store_data (
                id INT AUTO_INCREMENT PRIMARY KEY,
                store_name VARCHAR(200) NOT NULL,
                sido VARCHAR(50),
                sigungu VARCHAR(50),
                upjong VARCHAR(100),
                address VARCHAR(500),
                sales_amount BIGINT,
                reg_date DATE,
                
                -- 유니크 제약
                UNIQUE KEY uk_store_address (store_name, address)
            ) ENGINE=InnoDB DEFAULT CHARSET=utf8mb4
        """))
        conn.commit()
    
    return engine

def load_data_to_db():
    """CSV 데이터를 DB에 삽입"""
    # 1. 스키마 생성
    engine = setup_database()
    
    # 2. CSV 읽기
    df = pd.read_csv('소상공인데이터.csv', encoding='cp949')
    
    # 3. 전처리
    df.columns = df.columns.str.strip()
    df = df.fillna('')
    
    # 4. 데이터 삽입 (스키마는 이미 생성됨)
    df.to_sql(
        'store_data',
        engine,
        if_exists='append',  # replace 아님!
        index=False,
        chunksize=5000,
        method='multi'
    )
    
    print(f"{len(df):,}건 삽입 완료")
    
    # 5. 인덱스 확인
    with engine.connect() as conn:
        result = conn.execute(text("""
            SELECT INDEX_NAME, COLUMN_NAME, SEQ_IN_INDEX
            FROM information_schema.STATISTICS
            WHERE TABLE_SCHEMA = DATABASE()
            AND TABLE_NAME = 'store_data'
            ORDER BY INDEX_NAME, SEQ_IN_INDEX
        """))
        
        print("\n생성된 인덱스:")
        for row in result:
            print(f"  {row[0]}: {row[1]}")

if __name__ == '__main__':
    load_data_to_db()
